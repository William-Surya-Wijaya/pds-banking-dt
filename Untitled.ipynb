# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('Absenteeism_at_work.csv')

# %%
df2 = df[['Age','Education', 'Service time', 'Month of absence', 'Hit target']]

# %%
corr = df2.corr()
corr
# Out:
#                        Age  Education  Service time  Month of absence  \
# Age               1.000000  -0.221882      0.670979         -0.001520
# Education        -0.221882   1.000000     -0.213000         -0.066128
# Service time      0.670979  -0.213000      1.000000         -0.062862
# Month of absence -0.001520  -0.066128     -0.062862          1.000000
# Hit target       -0.039224   0.101062     -0.007840         -0.460453
#
#                   Hit target
# Age                -0.039224
# Education           0.101062
# Service time       -0.007840
# Month of absence   -0.460453
# Hit target          1.000000

# %%
sns.heatmap(corr, cmap="YlGnBu", annot = True)
plt.show()
